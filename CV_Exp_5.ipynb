# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishnubhatlapranav2004/11239A101_CV_Exp-s/blob/main/CV_Exp_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

import cv2
from google.colab.patches import cv2_imshow

img_path = next(iter(uploaded))
img = cv2.imread(img_path)

cv2_imshow(img)
# Out:
#      <input type="file" id="files-1b91aedd-e11b-4643-a31e-9c39d31ca5a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b91aedd-e11b-4643-a31e-9c39d31ca5a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
avg = cv2.blur(img, (5,5))
cv2_imshow(avg)
# Out:
# <PIL.Image.Image image mode=RGB size=525x350>

# %%
gaussian = cv2.GaussianBlur(img, (5,5), 0)
cv2_imshow(gaussian)
# Out:
# <PIL.Image.Image image mode=RGB size=525x350>

# %%
median = cv2.medianBlur(img, 5)
cv2_imshow(median)
# Out:
# <PIL.Image.Image image mode=RGB size=525x350>

# %%
bilateral = cv2.bilateralFilter(img, 9, 75, 75)
cv2_imshow(bilateral)
# Out:
# <PIL.Image.Image image mode=RGB size=525x350>

# %%
cv2_imshow(img)
cv2_imshow(avg)
cv2_imshow(gaussian)
cv2_imshow(median)
cv2_imshow(bilateral)
# Out:
# <PIL.Image.Image image mode=RGB size=525x350>
# <PIL.Image.Image image mode=RGB size=525x350>
# <PIL.Image.Image image mode=RGB size=525x350>
# <PIL.Image.Image image mode=RGB size=525x350>
# <PIL.Image.Image image mode=RGB size=525x350>
